# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunnidhya/Scientific-Python-Tutorial/blob/main/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Implement this pseudocode:**
# ```
# for i in {1,2...,N}
#   k <- random in {1,2,3}
#   xi <- 0.5xi-1  +  k-1
#   yi <- 0.5yi-1
#   if k is 2, yi <- yi-1 + 2
#
# plot dots for (x,y)
# ```

# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 444.2 kB/s eta 0:00:28
#    - -------------------------------------- 0.5/12.8 MB 444.2 kB/s eta 0:00:28
#    - -------------------------------------- 0.5/12.8 MB 444.2 kB/s eta 0:00:28
#    - -------------------------------------- 0.5/12.8 MB 444.2 kB/s eta 0:00:28
#    -- ------------------------------------- 0.8/12.8 MB 364.4 kB/s eta 0:00:33
#    --- ------------------------------------ 1.0/12.8 MB 465.7 kB/s eta 0:00:26
#    --- ------------------------------------ 1.0/12.8 MB 465.7 kB/s eta 0:00:26
#    ---- ----------------------------------- 1.3/12.8 MB 514.0 kB/s eta 0:00:23
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 10000 # We will have 10000 plots in my plot

# Initialize x and y vectors
sx = np.zeros(N)
sy = np.zeros(N)

for i in range(1,N):
  #Generate a random number {1,2,3}
  k = np.random.randint(1,4)

  # Update x and y points
  sx[i] = 0.5*sx[i-1] + k-1
  sy[i] = 0.5*sy[i-1]

  if k == 2:
    sy[i] += 2

plt.plot(sx,sy,'k.', markersize=1)
plt.title('Sierpinski Triangle')
plt.axis('off')
plt.show()

# This plots the Sierpinski triangle -> Fractals -> Keep on zooming in
# and you will see more traingles

# %% [markdown]
# -------------------Part 1--------------------

# %% [markdown]
# Data Types

# %%
a = 4
b = 3
print(a, b)
# Out:
# 4 3

# %%
d= 'Hello'
e = "Hey who's There!!"

# %%
print(d,e)
# Out:
# Hello Hey who's There!!

# %%
# This is a comment
'''
This is a multi line comment mainly used for 
function definition
'''
# Out:
# '\nThis is a multi line comment mainly used for \nfunction definition\n'

# %%
#multiple assignments
f, g = 10, 10
print (f, g)
# Out:
# 10 10

# %%
#How to check all variables used in the session
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# N          int        10000
# a          str        Hello
# b          int        3
# d          str        Hello
# e          str        Hey who's There!!
# f          int        10
# g          int        10
# i          int        9999
# k          int        1
# np         module     <module 'numpy' from 'c:\<...>ges\\numpy\\__init__.py'>
# plt        module     <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sx         ndarray    10000: 10000 elems, type `float64`, 80000 bytes
# sy         ndarray    10000: 10000 elems, type `float64`, 80000 bytes

# %%
a = 'Hello'

# %%
# A variable can both be overwritten with a different 
# value of the same data type
# or can as well be entirely overwritten with a new data
# type
